# %% [markdown]
# # Baseline script of SomaNews Clustering

# %%
import numpy as np
import pandas as pd
from konlpy.tag import Mecab
import hanja
import re
import string
import operator
import random
import matplotlib.pyplot as plt
import itertools
import cnouns
from sklearn.metrics import adjusted_rand_score
from sklearn.cross_validation import StratifiedKFold
from sklearn.cross_validation import cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from time import time
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load Data
# Load Data from database

# %%
df = pd.read_pickle("../datastore/whole_articles.p")
df = df.drop(['author', 'link', 'imageURL'], axis=1)
df.shape
# Out:
# (120835, 8)

# %% [markdown]
# ## Pick test set

# %%
topics = {0: u'올림픽',
          1: u'테러', 
          2: u'브렉시트', 
#           3: u'남중국해, 사드, 북핵',
          3: u'미국 금리',
          4: u'바이러스', 
          5: u'미국대선,힐러리,트럼프', 
          6: u'시리아 전쟁, 난민', 
#           7: u'미국 금리'
         }
test_set = {}

# %%
ts0_1 = df.loc[df.title.str.match(u"(?=.*올림픽)(?!.*장애인)(?!.*평창).*")]
test_set[0] = pd.concat([ts0_1], axis=0)

# %%
test_set[1] = pd.concat([df.loc[df.title.str.match(u"(?=.*테러)(?!.*방지법).*")]], axis=0)

# %%
ts2_1 = df[df.title.str.match(u"(?=.*브렉시트).*")]
ts2_2 = df[df.title.str.match(u"(?=.*EU)(?=.*탈퇴).*")]
test_set[2] = pd.concat([ts2_1, ts2_2], axis=0)

# %%
# ts9_1 = df[df.title.str.match(u"(?=.*남중국해).*")]
# ts9_2 = df[df.title.str.match(u"(?=.*사드)(?=.*일본)(?!.*아사드).*")]
# ts9_3 = df[df.title.str.match(u"(?=.*사드)(?=.*중국)(?!.*아사드).*")]
# ts9_4 = df[df.title.str.match(u"(?=.*사드)(?=.*미국)(?!.*아사드).*")]
# ts9_5 = df[df.title.str.match(u"(?=.*사드)(?=.*시진핑)(?!.*아사드).*")]
# ts9_6 = df[df.title.str.match(u"(?=.*사드)(?=.*오바마)(?!.*아사드).*")]
# ts9_7 = df[df.title.str.match(u"(?=.*북핵).*")]
# test_set[3] = pd.concat([ts9_1, ts9_2, ts9_3, ts9_4, ts9_5, ts9_6, ts9_7], axis=0)

# %%
ts4_1 = df[df.title.str.match(u"(?=.*지카).*")]
ts4_2 = df[df.title.str.match(u"(?=.*메르스).*")]
ts4_3 = df[df.title.str.match(u"(?=.*에볼라).*")]
ts4_4 = df[df.title.str.match(u"(?=.*바이러스).*")]
test_set[4] = pd.concat([ts4_1, ts4_2, ts4_3, ts4_4], axis=0)

# %%
ts5_1 = df[df.title.str.match(u"(?=.*힐러리).*")]
ts5_2 = df[df.title.str.match(u"(?=.*트럼프).*")]
ts5_3 = df[df.title.str.match(u"(?=.*클린턴).*")]
ts5_4 = df[df.title.str.match(u"(?=.*도날드)(?!.*맥도날드).*")]
test_set[5] = pd.concat([ts5_1, ts5_2, ts5_3, ts5_4], axis=0)

# %%
ts6_1 = df[df.title.str.match(u"(?=.*시리아).*")]
ts6_2 = df[df.title.str.match(u"(?=.*알레포).*")]
ts6_3 = df[df.title.str.match(u"(?=.*아사드).*")]
ts6_4 = df[df.title.str.match(u"(?=.*정부군).*")]
ts6_5 = df[df.title.str.match(u"(?=.*반군).*")]
ts3_6 = df[df.title.str.match(u"(?=.*난민).*")]
test_set[6] = pd.concat([ts6_1, ts6_2, ts6_3, ts6_4, ts6_5, ts3_6], axis=0)

# %%
ts8_1 = df[df.title.str.match(u"(?=.*연준).*")]
# ts8_2 = df[df.title.str.match(u"(?=.*양적완화)(?!.*한국).*")]
ts8_3 = df[df.title.str.match(u"(?=.*금리)(?=.*인상).*")]
ts8_4 = df[df.title.str.match(u"(?=.*기준)(?=.*금리).*")]
ts8_5 = df[df.title.str.match(u"(?=.*옐런).*")]
ts8_6 = df[df.title.str.match(u"(?=.*금리)(?=.*동결).*")]
ts8_7 = df[df.title.str.match(u"(?=.*금리)(?=.*경제).*")]
test_set[3] = pd.concat([ts8_1, ts8_3, ts8_4, ts8_5, ts8_6, ts8_7], axis=0)

# %%
# ts7_1 = df[df.title.str.match(u"(?=.*IS).*")]
# ts7_2 = df[df.title.str.match(u"(?=.*극단주의).*")]
# ts7_3 = df[df.title.str.match(u"(?=.*외로운 늑대).*")]
# test_set[7] = pd.concat([ts7_1, ts7_2, ts7_3], axis=0)

# %%
# ts9_1 = df[df.title.str.match(u"(?=.*남중국해).*")]
# ts9_2 = df[df.title.str.match(u"(?=.*사드)(?=.*일본)(?!.*아사드).*")]
# ts9_3 = df[df.title.str.match(u"(?=.*사드)(?=.*중국)(?!.*아사드).*")]
# ts9_4 = df[df.title.str.match(u"(?=.*사드)(?=.*미국)(?!.*아사드).*")]
# ts9_5 = df[df.title.str.match(u"(?=.*사드)(?=.*시진핑)(?!.*아사드).*")]
# ts9_6 = df[df.title.str.match(u"(?=.*사드)(?=.*오바마)(?!.*아사드).*")]
# ts9_7 = df[df.title.str.match(u"(?=.*북핵).*")]
# test_set[9] = pd.concat([ts9_1, ts9_2, ts9_3, ts9_4, ts9_5, ts9_6, ts9_7], axis=0)

# %%
for i in range(0, len(topics)):
    test_set[i]['topic'] = topics[i]
    test_set[i]['topic_idx'] = i
#     test_set[i] = test_set[i].sample(n=150)
    
test_set[5] = test_set[5].sample(n=500)

train_df = pd.concat([ts for ts in test_set.values()], axis=0)
# train_df

# %% [markdown]
# ## Preprocessing
# 1. Remove stopwords (regex, hanja)
# 2. POS Tagging with KoNLPy, Mecab

# %%
def text_cleaning(text):
    text = hanja.translate(text, 'substitution')
    text = re.sub(u'(\[.*\]|\(.*\))', '', text)
    text = re.sub(u'(\(|\)|\[|\])', '', text)
    return text

# %%
train_df['clean_title'] = [text_cleaning(t) for t in train_df.title]
train_df['clean_content'] = [text_cleaning(t) for t in train_df.content]

# %%
train_df['tokenized_title'] = [cnouns.tokenize(t) for t in train_df.clean_title]
train_df['tokenized_content'] = [cnouns.tokenize(t) for t in train_df.clean_content]

# %% [markdown]
# ## Save/Load Preprocessed data

# %%
train_df.to_pickle("../datastore/preprocesse.p")

# %%
train_df = pd.read_pickle("../datastore/w-preprocesse.p")

# %%
train_df.head
# Out:
# <bound method DataFrame.head of                              _id                                category  \
# 0       57e2c716149c2181df5b8b95                               사회 > 카드뉴스
# 1       57e2c716149c2181df5b8b96                               사회 > 카드뉴스
# 2       57e2c716149c2181df5b8b97                               사회 > 카드뉴스
# 3       57e2c716149c2181df5b8b98                             문화 > 오늘의 운세
# 4       57e2c723149c2181df5b8bad                       스포츠ㆍ연예 > 스포츠 > 종합
# 5       57e2c716149c2181df5b8b99                         nativeAD > 기업뉴스
# 6       57e2c717149c2181df5b8b9a                       사설ㆍ칼럼 > 내부칼럼 > 사설
# 7       57e2c717149c2181df5b8b9b                       사설ㆍ칼럼 > 내부칼럼 > 사설
# 8       57e2c717149c2181df5b8b9c                       사설ㆍ칼럼 > 내부칼럼 > 사설
# 9       57e2c717149c2181df5b8b9d  사설ㆍ칼럼 > 외부칼럼 > 시론ㆍ기고 > 朝鮮칼럼 The Column
# 10      57e2c717149c2181df5b8b9e                      사설ㆍ칼럼 > 내부칼럼 > 만물상
# 11      57e2c721149c2181df5b8b9f                 사설ㆍ칼럼 > 외부칼럼 > 정민의 세설신어
# 12      57e2c724149c2181df5b8bb5                             사고 > 바로잡습니다
# 13      57e2c72e149c2181df5b8bea                        사회 > 교육ㆍ시험 > 중국어
# 14      57e2c721149c2181df5b8ba0                  사설ㆍ칼럼 > 리스트칼럼 > 전문기자칼럼
# 15      57e2c721149c2181df5b8ba1                    사설ㆍ칼럼 > 외부칼럼 > 시론ㆍ기고
# 16      57e2c721149c2181df5b8ba2                  사설ㆍ칼럼 > 내부칼럼 > 트렌드 돋보기
# 17      57e2c722149c2181df5b8ba3                            사설ㆍ칼럼 > 내부칼럼
# 18      57e2c722149c2181df5b8ba4                     사설ㆍ칼럼 > 외부칼럼 > 경제초점
# 19      57e2c722149c2181df5b8ba5               사설ㆍ칼럼 > 외부칼럼 > 김기봉의 히스토리아
# 20      57e2c722149c2181df5b8ba6                    사설ㆍ칼럼 > 외부칼럼 > ESSAY
# 21      57e2c722149c2181df5b8ba7                 사설ㆍ칼럼 > 외부칼럼 > 가슴으로 읽는…
# 22      57e2c722149c2181df5b8ba8                      사설ㆍ칼럼 > 외부칼럼 > 발언대
# 23      57e2c723149c2181df5b8ba9                 스포츠ㆍ연예 > 엔터테인먼트 > TV/방송
# 24      57e2c723149c2181df5b8baa              스포츠ㆍ연예 > 스포츠 > 골프 > 여자해외골프
# 25      57e2c723149c2181df5b8bab                       스포츠ㆍ연예 > 스포츠 > 배구
# 26      57e2c723149c2181df5b8bac                  스포츠ㆍ연예 > 스포츠 > 종합 > 바둑
# 27      57e2c723149c2181df5b8bae                       스포츠ㆍ연예 > 스포츠 > 종합
# 28      57e2c723149c2181df5b8baf                       스포츠ㆍ연예 > 스포츠 > 종합
# 29      57e2c724149c2181df5b8bb0                       스포츠ㆍ연예 > 스포츠 > 종합
# ...                          ...                                     ...
# 120805  57e3b674149c2181df5d637a                               사회 > 사회일반
# 120806  57e3b679149c2181df5d637b                               경제 > 경제일반
# 120807  57e3b67a149c2181df5d637c                               사회 > 사회일반
# 120808  57e3b67b149c2181df5d637d                                 사회 > 전국
# 120809  57e3b67c149c2181df5d637e                                 사회 > 전국
# 120810  57e3b67d149c2181df5d637f                            스포츠 > 야구·MLB
# 120811  57e3b67e149c2181df5d6380                             국제 > 미국·중남미
# 120812  57e3b67f149c2181df5d6381                               사회 > 사회일반
# 120813  57e3b680149c2181df5d6382                                 사회 > 환경
# 120814  57e3b681149c2181df5d6383                                 사회 > 환경
# 120815  57e3b681149c2181df5d6384                               사회 > 사회일반
# 120816  57e3b682149c2181df5d6385                              사회 > 의료·건강
# 120817  57e3b683149c2181df5d6386                                 사회 > 노동
# 120818  57e3b684149c2181df5d6387                               사회 > 사회일반
# 120819  57e3b685149c2181df5d6388                                 국제 > 유럽
# 120820  57e3b689149c2181df5d6389                              사회 > 의료·건강
# 120821  57e3b699149c2181df5d638a                                 사회 > 전국
# 120822  57e3b69a149c2181df5d638b                                정치 > 청와대
# 120823  57e3b69b149c2181df5d638c                                 사회 > 전국
# 120824  57e3b69c149c2181df5d638d                              정치 > 국회·정당
# 120825  57e3b69d149c2181df5d638e                               경제 > 경제일반
# 120826  57e3b69e149c2181df5d638f                              정치 > 국회·정당
# 120827  57e3b69f149c2181df5d6390                               사회 > 사회일반
# 120828  57e3b6a0149c2181df5d6391                                 사회 > 전국
# 120829  57e3b6a1149c2181df5d6392                              문화 > 방송·연예
# 120830  57e3b6a4149c2181df5d6393                                 국제 > 유럽
# 120831  57e3b6a6149c2181df5d6394                            스포츠 > 야구·MLB
# 120832  57e3b6a9149c2181df5d6395                              정치 > 국회·정당
# 120833  57e3b6aa149c2181df5d6396                               사회 > 사회일반
# 120834  57e3b6ab149c2181df5d6397                               사회 > 사회일반
#
#                                                   content  \
# 0       과연 진실은... \n[ 조선일보 카드뉴스가 더 보고 싶다면 ?] \n\n[ 조선일...
# 1       '세기의 연인'이라 불렸던 커플\n\n[ 조선일보 카드뉴스가 더 보고 싶다면 ?] ...
# 2       당신의 목소리는 그 누구의 목소리보다 귀하게 쓰였습니다.  기사보기 : https:...
# 3       36년생 정도를 지키면 무난한 날. 48년생 결정할 일 결정하도록. 60년생 가뭄에...
# 4
# 5       국내에서 운행 중인 자동차 가운데 리콜(회수 후 시정 조치) 대상임에도 수리를 받지...
# 6       추석 연휴 전후로 두 차례 지진을 겪은 영남 지역 주민들의 공포와 불안감이 심각하다...
# 7       중국 정부가 우라늄 정제에 필수적인 산화알루미늄을 비롯, 핵·미사일 개발에 언제든지...
# 8       롯데그룹 수사의 정점에 있는 신동빈 롯데그룹 회장이 20일 피의자 신분으로 검찰에 ...
# 9       노령연금의 역사는 19세기 말로 거슬러 올라간다. 부국강병책으로 독일을 통일하고 독...
# 10      인사혁신처가 '전문직 공무원' 제도를 도입하겠다고 했다. 국제 통상, 재난·안전처럼...
# 11      아침저녁 소매 끝에 느껴지는 기운이 선뜻하다. 송강(松江) 정철(鄭澈)의 '산사야음...
# 12      19일자 A24면 '전 인지, 우즈도 박인비도 뛰어넘다'(53판) 기사의 사진에서 ...
# 13
# 14      서울의 한 유명 대학병원 수술실. 월요일부터 목요일까지는 아침부터 저녁까지 빈 수술...
# 15      리우 패럴림픽에서 메달 수여자로 '보치아' 금메달리스트 정호원 선수와 대기장에서 기...
# 16      15년 전 사회부 초년 기자 때였다. 가출과 원조 교제, 노숙 등 사회적 이슈가 되...
# 17      1973년 시내버스로 출퇴근하던 70세의 의사 김모씨는 매일 수첩에 특별한 기록을 ...
# 18      올 초 다보스포럼에서 4차 산업혁명이 주목받은 이후 대응책 마련에 정부가 분주하더니...
# 19      북한 핵 앞에 대한민국이 풍전등화다. 정치란 바름(正)을 실행하는 것이고 지배자는 ...
# 20      직장에 다닐 수 있는 시기를 하루 중 낮이라고 한다면, 퇴직 후의 삶은 저녁이다. ...
# 21      지글짝 뽀글짝\n\n엄마가 주방에서 저녁을 짓습니다\n지글짝 뽀글짝\n아빠가 옆에서...
# 22      경주에서 규모 5.8의 지진이 발생하더니 일주일 만에 규모 4.5의 여진이 일어나 ...
# 23      TV조선은 21일 밤 11시 시사 토크쇼 '강적들'을 방송한다.\n\n19대 대선을...
# 24      미국여자프로골프(LPGA) 투어 시즌 마지막 메이저대회인 에비앙 챔피언십에서 준우승...
# 25      한국 배구를 총괄하는 대한배구협회(KVA)와 프로를 관할하는 한국배구연맹(KOVO)...
# 26      〈총보〉 (1~182)=박영훈(31)의 9월 랭킹은 박정환, 이세돌에 이은 3위다....
# 27      내달 5일 치러지는 제40대 대한체육회 회장 선거를 앞두고 '한치 앞을 볼 수 없다...
# 28      러시아의 반격인가.\n\n러시아 해커 집단이 세계반도핑기구(WADA)의 데이터베이스...
# 29      코리아오픈테니스 한국 전원 탈락\n장수정(세계 171위)이 20일 한국에서 열리는 ...
# ...                                                   ...
# 120805  행정자치부가 전국 지방자치단체의 축제·행사 집행비(원가)를 전면 공개하기로 했다. ...
# 120806  박근혜 대통령의 제안으로 시중은행 5곳이 청년희망펀드를 출시한 가운데 케이이비(KE...
# 120807  법무부는 국가를 상대로 한 부패와 비리, 불법 집단행동으로 일어난 국고 손실을 전담...
# 120808  22일 오후 1시20분께 강원 철원군 서면 와수리에서 육군 상사로 전역한 ㄱ(50)...
# 120809  농촌진흥청(농진청)이 직원 자녀를 계약직으로 채용했다가 무기계약직으로 바꿔준 것으로...
# 120810  2008년 6월4일은 한국 야구팬들이 최악의 모욕을 느껴야 했던 날이다. 광주에서 ...
# 120811  100미터를 전력질주하고, 원반과 포환을 던지며, 장대높이뛰기에 도전하는 100살 ...
# 120812  길거리 음란 행위로 물의를 빚어 사직한 김수창(53·사법연수원 19기) 전 제주지검...
# 120813  소주·맥주 등 빈병 값 인상이 예고된 가운데 대형마트에 빈병 무인회수기가 설치된다....
# 120814  22일 서울의 낮 최고기온이 31도까지 올라가 9월 하순 날씨로는 50년 만에 가장...
# 120815  가족 장례에서 화장을 선택한 사람 중에 자연장(수목장 및 잔디장)을 이용한 사례가 ...
# 120816  전국 성형외과 10곳 가운데 7~8곳이 건강보험 진료비를 한 건도 청구하지 않은 것...
# 120817  쌍용자동차 해고자들이 해고자 복직 문제 해결을 위해 대주주인 마힌드라그룹이 있는 인...
# 120818  김순옥이 돌아왔다. 예전 같았으면 이 문장 주어의 자리엔 이른바 ‘막장드라마 대모’...
# 120819  영국 노동당의 새로운 당대표로 뽑힌 제러미 코빈이 주목받고 있다. 미국 민주당 대선...
# 120820  한겨레 자료사진   \n동양의학에서는 예로부터 식품과 약이 구분되지 않았다. 날마다...
# 120821  중동호흡기증후군(메르스) 때문에 취소가 많아 해외여행을 싸게 갈 수 있다고 속여 3...
# 120822  최재천 새정치민주연합 정책위의장은 22일 박근혜 대통령이 추석을 앞두고 모든 국군 ...
# 120823  산림청 국립수목원은 세계유산·한라산연구원과 함께 국가 지정 희귀식물인 ‘비자란’의 ...
# 120824  박주선 새정치민주연합 의원. 이정우 선임기자 woo@hani.co.kr 2014.1...
# 120825  추석명절을 앞둔 22일 서울 중구 한국은행 본점에서 직원들이 추석자금을 시중은행에 ...
# 120826  박주선 새정치민주연합 의원이 22일 오후 국회 정론관에서 기자회견을 열어 탈당을 선...
# 120827  한겨레가 선보이는 ’버티컬 동영상’은 모바일 중심 콘텐츠입니다. 스마트폰을 가로로 ...
# 120828  자신의 맘에 들지 않는다는 이유로 수년 동안 제자를 때리고 인분을 먹이는 등 가혹행...
# 120829  배우 이민호(28)와 그룹 미쓰에이의 수지(21)의 결별설이 사실이 아닌 것으로 밝...
# 120830  데이비드 캐머런 영국 총리가 21일(현지 시간) 런던 다우닝가 총리 관저에서 라르스...
# 120831  우문이었는지 모른다. 하지만 궁금했다. 21일 마산 엔시(NC)전에서 케이비오(KB...
# 120832  박주선 새정치민주연합 의원. 이정우 선임기자 woo@hani.co.kr 2014.1...
# 120833  9월22일 뉴스 브리핑\n가 매일 아침 에 실린 수많은 콘텐츠 가운데 주요 콘텐츠 ...
# 120834  한국사 교과서 국정화에 반대하는 각계 성명이 잇따르는 가운데 연세대 교수들도 국정화...
#
#                                               description provider  \
# 0                                                           chosun
# 1                                                           chosun
# 2                                                           chosun
# 3                                                           chosun
# 4                                                           chosun
# 5                     르노삼성, 리콜 가장 성실 이행… 혼다코리아는 시정률 절반 불과   chosun
# 6                                                           chosun
# 7                                                           chosun
# 8                                                           chosun
# 9       연금 위기 근본적 해결하려면 OECD 평균 절반 수준인 국민연금 보험료 현실화해야\...   chosun
# 10                                                          chosun
# 11                                                          chosun
# 12                                                          chosun
# 13                                                          chosun
# 14                                                          chosun
# 15                                                          chosun
# 16                                                          chosun
# 17                                                          chosun
# 18      4차 산업혁명 대전환기에 정부는 사물인터넷·인공지능 등 집중 육성 강조하지만\n특정...   chosun
# 19                                                          chosun
# 20      퇴직 후 시작한 무모한 농촌 생활… 별 보고 나가 별 보고 귀가하는\n정신없이 바쁜...   chosun
# 21                                                          chosun
# 22                                                          chosun
# 23                                       TV조선 '강적들' 밤 11시   chosun
# 24                      모레 미래에셋대우클래식 개막\n장타자 박성현·김세영 같은 조   chosun
# 25      선수 양성 힘써도 모자랄 판에 대한배구협회·한국배구연맹\nAVC컵 대표팀 선수 차출...   chosun
# 26      본선 1회전 제5국 <흑 6집반 공제·각 3시간>\n白 박영훈 九단 / 黑 자오천위 四단   chosun
# 27      - 10월 5일 대한체육회장 선거\n예전엔 대의원 50명이 뽑았지만 이번엔 선거인단...   chosun
# 28      [러시아 해커들, 바일스·나달 등 66명의 치료용 약물기록 빼내… 스포츠계 충격]\...   chosun
# 29                                                          chosun
# ...                                                   ...      ...
# 120805                                                        hani
# 120806  계약직까지 포함 1인1계좌 동원령\n지점별 가입률 집계 ‘실적경쟁’\n액수 정해주거...     hani
# 120807  국가 상대 부패·비리 따른 손실 소송 전담\n집회·시위에 따른 피해도 적극 대응 방...     hani
# 120808                                                        hani
# 120809                                                        hani
# 120810         [한겨레21]\n롯데전서 우천으로 인한 노게임 선언 노린 것으로 보이는 한화     hani
# 120811  미 시니어 올림픽에서 노익장 과시한 돈 펠먼\n투포환·원반던지기 등 5개 종목서 세...     hani
# 120812                                                        hani
# 120813              환경부, 전국 8곳에서 시범 운영\n빈병값 인상과 함께 시너지 기대     hani
# 120814                        기상청 “강한 햇볕에 남동풍까지 불어 이상 기온”     hani
# 120815                            장례부터 장묘까지 비용은 평균 1400만원     hani
# 120816                                   환자에게 모두 청구했을 가능성     hani
# 120817  김정욱 쌍용차지부 사무국장 등 5명\n마힌드라그룹 상대 원정투쟁 나서\n“7년 고통...     hani
# 120818  [한겨레21] 김순옥 작가를 필두로 열리고 있는 ‘막드’의 새로운 시대\n막장드라마...     hani
# 120819  [한겨레21]  제러미 코빈 새 당대표가 쓴 ‘드라마’\n\n후보되기도 힘겨웠으나 ...     hani
# 120820  section _ H \n 다섯 가지 맛이 각각 다른 효능\n평소에 물 대신 활용해...     hani
# 120821                                경찰, 여행사 대표 영장 신청하기로     hani
# 120822  특별 사면·특별 공휴일·특별 휴가증·특별 간식 등 잇따라\n새정치 최재천 “민주공화...     hani
# 120823                                                        hani
# 120824                     “새정치연합 사망선고 받아…새로운 대안 정치세력 건설”     hani
# 120825                                                        hani
# 120826                                                        hani
# 120827                                                        hani
# 120828                                                        hani
# 120829                                                        hani
# 120830  옥스포드 재학 당시 마리화나 등 복용\n가난한 사람 경멸하는 사교클럽 활동\n입회식...     hani
# 120831                                                        hani
# 120832                            박 의원 “새 대안 세력 건설 위해 탈당”     hani
# 120833                                                        hani
# 120834              “국정화는 유신독재 권력이 역사 해석마저 과거로 회귀 시도하는 것”     hani
#
#        providerNewsID         publishedAt  \
# 0       2016092103107 2016-09-21 19:28:00
# 1       2016092103074 2016-09-21 19:10:00
# 2       2016092103038 2016-09-21 19:03:00
# 3       2016091302249 2016-09-21 18:00:00
# 4       2016092100090 2016-09-21 03:00:00
# 5       2016092101066 2016-09-21 10:45:00
# 6       2016092003130 2016-09-21 03:15:00
# 7       2016092003132 2016-09-21 03:14:00
# 8       2016092003134 2016-09-21 03:13:00
# 9       2016092003146 2016-09-21 03:12:00
# 10      2016092003157 2016-09-21 03:11:00
# 11      2016092003180 2016-09-21 03:10:00
# 12      2016092100213 2016-09-21 03:00:00
# 13      2016092100059 2016-09-21 03:00:00
# 14      2016092003137 2016-09-21 03:09:00
# 15      2016092003144 2016-09-21 03:08:00
# 16      2016092003148 2016-09-21 03:07:00
# 17      2016092003166 2016-09-21 03:06:00
# 18      2016092003170 2016-09-21 03:05:00
# 19      2016092003174 2016-09-21 03:04:00
# 20      2016092003182 2016-09-21 03:03:00
# 21      2016092003159 2016-09-21 03:02:00
# 22      2016092003168 2016-09-21 03:01:00
# 23      2016092003120 2016-09-21 03:00:00
# 24      2016092100029 2016-09-21 03:00:00
# 25      2016092100110 2016-09-21 03:00:00
# 26      2016092003112 2016-09-21 03:00:00
# 27      2016092100027 2016-09-21 03:00:00
# 28      2016092100126 2016-09-21 03:00:00
# 29      2016092100108 2016-09-21 03:00:00
# ...               ...                 ...
# 120805         709917 2015-09-22 18:04:00
# 120806         709916 2015-09-22 18:01:00
# 120807         709915 2015-09-22 17:43:00
# 120808         709914 2015-09-22 17:08:00
# 120809         709913 2015-09-22 17:07:00
# 120810         709912 2015-09-22 16:53:00
# 120811         709911 2015-09-22 16:49:00
# 120812         709910 2015-09-22 16:19:00
# 120813         709909 2015-09-22 16:13:00
# 120814         709908 2015-09-22 16:13:00
# 120815         709907 2015-09-22 16:11:00
# 120816         709906 2015-09-22 15:59:00
# 120817         709905 2015-09-22 15:53:00
# 120818         709904 2015-09-22 15:53:00
# 120819         709902 2015-09-22 15:30:00
# 120820         709901 2015-09-22 15:27:00
# 120821         709900 2015-09-22 15:14:00
# 120822         709899 2015-09-22 15:08:00
# 120823         709898 2015-09-22 14:21:00
# 120824         709897 2015-09-22 13:59:00
# 120825         709896 2015-09-22 13:54:00
# 120826         709895 2015-09-22 13:53:00
# 120827         709894 2015-09-22 13:09:00
# 120828         709893 2015-09-22 11:48:00
# 120829         709888 2015-09-22 11:26:00
# 120830         709885 2015-09-22 11:05:00
# 120831         709882 2015-09-22 10:26:00
# 120832         709881 2015-09-22 09:58:00
# 120833         709879 2015-09-22 08:50:00
# 120834         709878 2015-09-22 08:17:00
#
#                                                     title  \
# 0                              [카드뉴스] 대통령은 왜 흙을 밟지 않았을까요?
# 1                                   [카드뉴스] '브란젤리나'의 시작과 끝
# 2                           [카드뉴스] 목소리를 가장 귀하게 쓴 한 성우 지망생
# 3                       [오늘의 운세] 9월 22일 목요일(음력 8월 22일 丁未)
# 4                                   [오늘의 경기] 2016년 9월 21일
# 5                         리콜 대상인데도 버젓이… 결함 차량 72만대 도로 주행중
# 6                       [사설] 국민은 불안한데 무용지물 안전處는 정부 내 안전지대
# 7                           [사설] 美가 증거 내밀자 수사 나선 中 이중 플레이
# 8                       [사설] 신동빈 회장 소환, 이제 '롯데 리스크' 해소할 때
# 9                   [朝鮮칼럼 The Column] 고령화와 저금리 덫에 걸린 국민연금
# 10                                        [만물상] '전문직 공무원'
# 11                           [정민의 世說新語] [384] 과성당살 (過盛當殺)
# 12      [바로잡습니다] 19일자 A24면 '전인지, 우즈도 박인비도 뛰어넘다'(53판) 기사 외
# 13                                    [매일매일 중국어 한마디] 진정해요
# 14                          [전문기자 칼럼] '두 환자 동시 수술' 관행 바꿔야
# 15                         [기고] '패럴림픽 퍼스트'의 각오로 평창 대회 준비를
# 16                                 [트렌드 돋보기] 잘 자란 '오빠 부대'
# 17      [김명환의 시간여행] [36] 노인에게 버스 좌석 양보 않으면 단속… 대통령이 "자...
# 18                          [경제초점] 4차 산업혁명이 '러다이트 운동' 부를까
# 19           [김기봉의 히스토리아 쿠오바디스] [13] 마키아벨리에게 묻는 국가 위기의 해법
# 20                                      [ESSAY] 일흔에도 꽃씨처럼
# 21                                   [가슴으로 읽는 동시] 지글짝 뽀글짝
# 22                                 [발언대] 지진보험 도입, 정부가 나서라
# 23                                   [TV조선] 대권에 나설 7인의 잠룡
# 24                                          장타 여왕들의 한판 승부
# 25                                          싸우느라 정신없는 배구판
# 26                             [제21회 LG배 조선일보 기왕전] 박영훈 完勝
# 27                                 내달 '스포츠 사령관' 선거 누가 웃을까
# 28                             러시아의 복수? 스타선수들 금지약물 해킹해 폭로
# 29                          [스포츠 브리핑] 코리아오픈테니스 한국 전원 탈락 외
# ...                                                   ...
# 120805                 지역축제 원가 내달 모두 공개…‘재정난’인천, 축제·행사 늘려
# 120806                     하나은행, 전직원에게 ‘박 대통령 청년펀드’ 가입 지시
# 120807                                 법무부, 국고손실 환수송무팀 출범
# 120808                            수류탄 소지 추정 퇴역군인 철원서 행방불명
# 120809                      농촌진흥청도 음서제 논란…“직원자녀 채용 특혜 의혹”
# 120810                       한화 ‘관중 모욕’…7년 전 악몽 재현하려 했는가!
# 120811               100미터 26초99 세계신기록…100살 할아버지의 아름다운 도전
# 120812                      ‘음란 행위’ 김수창 전 제주지검장 변호사 등록 허가
# 120813                         대형마트에 빈병 무인회수기 설치…회수율 높아질까
# 120814                 서울 낮 최고기온 31도…9월 하순으론 50년 만에 가장 더워
# 120815                             장례 때 가장 많은 장묘 방식은 ‘화장’
# 120816                     강남 성형외과 92% ‘건보 진료비’ 청구 안해, 왜?
# 120817                  “‘희망고문’ 끊겠다”…쌍용차 해고자들, 대주주 찾아 인도로
# 120818                                   욕하면서 보는 ‘막드’의 변신
# 120819                     ‘변방 좌파’가 대표 뽑힌 날, 영국 노동당이 돌아왔다
# 120820                                   물 대신 마시면 좋은 오미자차
# 120821                 “메르스 탓에 해외여행 싸게 갈 수 있다” 속여 여행비 가로채
# 120822                         왕이 백성에게 나눠주듯…박 대통령 ‘특별’ 남발
# 120823                                희귀식물 ‘비자란’ 자생지 복원한다
# 120824                            박주선, 새정치 탈당…현역 의원 탈당 1호
# 120825                      [포토] 추석 맞이 ‘현금 대방출’…금고 연 한국은행
# 120826                       [전문] 박주선 의원 새정치민주연합 탈당 기자회견문
# 120827                     [버티컬 동영상] 청계재단, 세상에서 가장 이상한 기부
# 120828                      검찰, 제자 가혹행위 ‘인분 교수’ 징역 10년 구형
# 120829                                 이민호·수지, 6개월 만에 결별?
# 120830                   캐머런 영국 총리 ‘피그게이트’ 파문… SNS 패러디 봇물
# 120831                       2년 연속 50홈런 박병호, “내게 홈런은 00다”
# 120832                 [속보] 박주선, 새정치 의원 중 첫 탈당…오늘 오후 기자회견
# 120833              [배달의 한겨레] “인천공항 해킹 여권번호 등 유출” 실토? 착각?
# 120834                    연세대 교수 132명 “한국사 교과서 국정화 반대” 성명
#
#                                          clean_title  \
# 0                                대통령은 왜 흙을 밟지 않았을까요?
# 1                                     '브란젤리나'의 시작과 끝
# 2                             목소리를 가장 귀하게 쓴 한 성우 지망생
# 3                                         9월 22일 목요일
# 4                                       2016년 9월 21일
# 5                    리콜 대상인데도 버젓이… 결함 차량 72만대 도로 주행중
# 6                       국민은 불안한데 무용지물 안전처는 정부 내 안전지대
# 7                           미가 증거 내밀자 수사 나선 중 이중 플레이
# 8                       신동빈 회장 소환, 이제 '롯데 리스크' 해소할 때
# 9                                고령화와 저금리 덫에 걸린 국민연금
# 10                                         '전문직 공무원'
# 11                                             과성당살
# 12               19일자 A24면 '전인지, 우즈도 박인비도 뛰어넘다' 기사 외
# 13                                              진정해요
# 14                               '두 환자 동시 수술' 관행 바꿔야
# 15                         '패럴림픽 퍼스트'의 각오로 평창 대회 준비를
# 16                                      잘 자란 '오빠 부대'
# 17       노인에게 버스 좌석 양보 않으면 단속… 대통령이 "자리 양보 풍습 확대" 강조
# 18                            4차 산업혁명이 '러다이트 운동' 부를까
# 19                              마키아벨리에게 묻는 국가 위기의 해법
# 20                                         일흔에도 꽃씨처럼
# 21                                           지글짝 뽀글짝
# 22                                  지진보험 도입, 정부가 나서라
# 23                                     대권에 나설 7인의 잠룡
# 24                                     장타 여왕들의 한판 승부
# 25                                     싸우느라 정신없는 배구판
# 26                                            박영훈 완승
# 27                            내달 '스포츠 사령관' 선거 누가 웃을까
# 28                        러시아의 복수? 스타선수들 금지약물 해킹해 폭로
# 29                               코리아오픈테니스 한국 전원 탈락 외
# ...                                              ...
# 120805            지역축제 원가 내달 모두 공개…‘재정난’인천, 축제·행사 늘려
# 120806                하나은행, 전직원에게 ‘박 대통령 청년펀드’ 가입 지시
# 120807                            법무부, 국고손실 환수송무팀 출범
# 120808                       수류탄 소지 추정 퇴역군인 철원서 행방불명
# 120809                 농촌진흥청도 음서제 논란…“직원자녀 채용 특혜 의혹”
# 120810                  한화 ‘관중 모욕’…7년 전 악몽 재현하려 했는가!
# 120811          100미터 26초99 세계신기록…100살 할아버지의 아름다운 도전
# 120812                 ‘음란 행위’ 김수창 전 제주지검장 변호사 등록 허가
# 120813                    대형마트에 빈병 무인회수기 설치…회수율 높아질까
# 120814            서울 낮 최고기온 31도…9월 하순으론 50년 만에 가장 더워
# 120815                        장례 때 가장 많은 장묘 방식은 ‘화장’
# 120816                강남 성형외과 92% ‘건보 진료비’ 청구 안해, 왜?
# 120817             “‘희망고문’ 끊겠다”…쌍용차 해고자들, 대주주 찾아 인도로
# 120818                              욕하면서 보는 ‘막드’의 변신
# 120819                ‘변방 좌파’가 대표 뽑힌 날, 영국 노동당이 돌아왔다
# 120820                              물 대신 마시면 좋은 오미자차
# 120821            “메르스 탓에 해외여행 싸게 갈 수 있다” 속여 여행비 가로채
# 120822                    왕이 백성에게 나눠주듯…박 대통령 ‘특별’ 남발
# 120823                           희귀식물 ‘비자란’ 자생지 복원한다
# 120824                       박주선, 새정치 탈당…현역 의원 탈당 1호
# 120825                      추석 맞이 ‘현금 대방출’…금고 연 한국은행
# 120826                       박주선 의원 새정치민주연합 탈당 기자회견문
# 120827                          청계재단, 세상에서 가장 이상한 기부
# 120828                 검찰, 제자 가혹행위 ‘인분 교수’ 징역 10년 구형
# 120829                            이민호·수지, 6개월 만에 결별?
# 120830              캐머런 영국 총리 ‘피그게이트’ 파문… SNS 패러디 봇물
# 120831                  2년 연속 50홈런 박병호, “내게 홈런은 00다”
# 120832                 박주선, 새정치 의원 중 첫 탈당…오늘 오후 기자회견
# 120833                   “인천공항 해킹 여권번호 등 유출” 실토? 착각?
# 120834               연세대 교수 132명 “한국사 교과서 국정화 반대” 성명
#
#                                             clean_content  \
# 0                                       과연 진실은... \n \n\n
# 1                              '세기의 연인'이라 불렸던 커플\n\n \n\n
# 2       당신의 목소리는 그 누구의 목소리보다 귀하게 쓰였습니다.  기사보기 : https:...
# 3       36년생 정도를 지키면 무난한 날. 48년생 결정할 일 결정하도록. 60년생 가뭄에...
# 4
# 5       국내에서 운행 중인 자동차 가운데 리콜는 리콜 판정을 받고도 아무런 조치를 하지 않...
# 6       추석 연휴 전후로 두 차례 지진을 겪은 영남 지역 주민들의 공포와 불안감이 심각하다...
# 7       중국 정부가 우라늄 정제에 필수적인 산화알루미늄을 비롯, 핵·미사일 개발에 언제든지...
# 8       롯데그룹 수사의 정점에 있는 신동빈 롯데그룹 회장이 20일 피의자 신분으로 검찰에 ...
# 9       노령연금의 역사는 19세기 말로 거슬러 올라간다. 부국강병책으로 독일을 통일하고 독...
# 10      인사혁신처가 '전문직 공무원' 제도를 도입하겠다고 했다. 국제 통상, 재난·안전처럼...
# 11      아침저녁 소매 끝에 느껴지는 기운이 선뜻하다. 송강." 저녁까지 맑았는데 밤 들어 ...
# 12      19일자 A24면 '전 인지, 우즈도 박인비도 뛰어넘다'이기에 바로잡습니다.\n\n...
# 13
# 14      서울의 한 유명 대학병원 수술실. 월요일부터 목요일까지는 아침부터 저녁까지 빈 수술...
# 15      리우 패럴림픽에서 메달 수여자로 '보치아' 금메달리스트 정호원 선수와 대기장에서 기...
# 16      15년 전 사회부 초년 기자 때였다. 가출과 원조 교제, 노숙 등 사회적 이슈가 되...
# 17      1973년 시내버스로 출퇴근하던 70세의 의사 김모씨는 매일 수첩에 특별한 기록을 ...
# 18      올 초 다보스포럼에서 4차 산업혁명이 주목받은 이후 대응책 마련에 정부가 분주하더니...
# 19      북한 핵 앞에 대한민국이 풍전등화다. 정치란 바름을 추구해야 한다는 공자님 말씀을 ...
# 20      직장에 다닐 수 있는 시기를 하루 중 낮이라고 한다면, 퇴직 후의 삶은 저녁이다. ...
# 21      지글짝 뽀글짝\n\n엄마가 주방에서 저녁을 짓습니다\n지글짝 뽀글짝\n아빠가 옆에서...
# 22      경주에서 규모 5.8의 지진이 발생하더니 일주일 만에 규모 4.5의 여진이 일어나 ...
# 23      TV조선은 21일 밤 11시 시사 토크쇼 '강적들'을 방송한다.\n\n19대 대선을...
# 24      미국여자프로골프 투어에서 시즌 8승째에 도전한다.\n\n무대는 23일부터 강원도 춘...
# 25      한국 배구를 총괄하는 대한배구협회이 외국인 선수 등록 문제를 놓고 진흙탕 싸움을 벌...
# 26      〈총보〉 '도 큰 몫을 하고 있다.\n\n이 판엔 박영훈 바둑의 장점과 단점이 모두...
# 27      내달 5일 치러지는 제40대 대한체육회 회장 선거를 앞두고 '한치 앞을 볼 수 없다...
# 28      러시아의 반격인가.\n\n러시아 해커 집단이 세계반도핑기구에는 아예 출전하지 못했다...
# 29      코리아오픈테니스 한국 전원 탈락\n장수정에게 0대2로 패했다. 장수정의 패배로 코리...
# ...                                                   ...
# 120805  행정자치부가 전국 지방자치단체의 축제·행사 집행비를 전면 공개하기로 했다. 재정위기...
# 120806  박근혜 대통령의 제안으로 시중은행 5곳이 청년희망펀드를 출시한 가운데 케이이비하나은...
# 120807  법무부는 국가를 상대로 한 부패와 비리, 불법 집단행동으로 일어난 국고 손실을 전담...
# 120808  22일 오후 1시20분께 강원 철원군 서면 와수리에서 육군 상사로 전역한 ㄱ씨가 ‘...
# 120809  농촌진흥청이 직원 자녀를 계약직으로 채용했다가 무기계약직으로 바꿔준 것으로 드러나 ...
# 120810  2008년 6월4일은 한국 야구팬들이 최악의 모욕을 느껴야 했던 날이다. 광주에서 ...
# 120811  100미터를 전력질주하고, 원반과 포환을 던지며, 장대높이뛰기에 도전하는 100살 ...
# 120812  길거리 음란 행위로 물의를 빚어 사직한 김수창 전 제주지검장이 변호사로 활동하게 됐...
# 120813  소주·맥주 등 빈병 값 인상이 예고된 가운데 대형마트에 빈병 무인회수기가 설치된다....
# 120814  22일 서울의 낮 최고기온이 31도까지 올라가 9월 하순 날씨로는 50년 만에 가장...
# 120815  가족 장례에서 화장을 선택한 사람 중에 자연장으로 나타났다. 장례부터 장묘까지 총 ...
# 120816  전국 성형외과 10곳 가운데 7~8곳이 건강보험 진료비를 한 건도 청구하지 않은 것...
# 120817  쌍용자동차 해고자들이 해고자 복직 문제 해결을 위해 대주주인 마힌드라그룹이 있는 인...
# 120818  김순옥이 돌아왔다. 예전 같았으면 이 문장 주어의 자리엔 이른바 ‘막장드라마 대모’...
# 120819  영국 노동당의 새로운 당대표로 뽑힌 제러미 코빈이 주목받고 있다. 미국 민주당 대선...
# 120820  한겨레 자료사진   \n동양의학에서는 예로부터 식품과 약이 구분되지 않았다. 날마다...
# 120821  중동호흡기증후군 때문에 취소가 많아 해외여행을 싸게 갈 수 있다고 속여 3500여만...
# 120822  최재천 새정치민주연합 정책위의장은 22일 박근혜 대통령이 추석을 앞두고 모든 국군 ...
# 120823  산림청 국립수목원은 세계유산·한라산연구원과 함께 국가 지정 희귀식물인 ‘비자란’의 ...
# 120824  박주선 새정치민주연합 의원. 이정우 선임기자 woo@hani.co.kr 2014.1...
# 120825  추석명절을 앞둔 22일 서울 중구 한국은행 본점에서 직원들이 추석자금을 시중은행에 ...
# 120826  박주선 새정치민주연합 의원이 22일 오후 국회 정론관에서 기자회견을 열어 탈당을 선...
# 120827  한겨레가 선보이는 ’버티컬 동영상’은 모바일 중심 콘텐츠입니다. 스마트폰을 가로로 ...
# 120828  자신의 맘에 들지 않는다는 이유로 수년 동안 제자를 때리고 인분을 먹이는 등 가혹행...
# 120829  배우 이민호의 결별설이 사실이 아닌 것으로 밝혀졌다.\n22일 오전 한 매체는 이민...
# 120830  데이비드 캐머런 영국 총리가 21일 런던 다우닝가 총리 관저에서 라르스 뢰케 라스무...
# 120831  우문이었는지 모른다. 하지만 궁금했다. 21일 마산 엔시에게 ‘홈런’은 어떤 의미인...
# 120832  박주선 새정치민주연합 의원. 이정우 선임기자 woo@hani.co.kr 2014.1...
# 120833  9월22일 뉴스 브리핑\n가 매일 아침 에 실린 수많은 콘텐츠 가운데 주요 콘텐츠 ...
# 120834  한국사 교과서 국정화에 반대하는 각계 성명이 잇따르는 가운데 연세대 교수들도 국정화...
#
#                                           tokenized_title  \
# 0                                                   대통령 흙
# 1                                         브란 젤리 시작 끝 브란젤리
# 2                                        목소리 성우 지망생 성우지망생
# 3                                                     목요일
# 4
# 5                        리콜 대상 결함 차량 도로 주행 리콜대상 결함차량 도로주행
# 6        국민 불안 무용지물 안전 처 정부 안전 지대 무용지물안전 안전처 안전지대 무용지물안전처
# 7                       미 증거 수사 나선 이중 플레이 수사나선 이중플레이 미가증거
# 8          신동빈 회장 소환 롯데 리스크 해소 때 신동빈회장 회장소환 롯데리스크 신동빈회장소환
# 9                                      고령 저금리 덫 국민연금 저금리덫
# 10                                         전문직 공무원 전문직공무원
# 11                                    과 성당 살 과성당 성당살 과성당살
# 12                                       일자 면 전 우즈 박인비 기사
# 13
# 14                           환자 동시 수술 관행 환자동시 동시수술 환자동시수술
# 15          패럴림픽 퍼스트 각오 평창 대회 준비 패럴림픽퍼스트 평창대회 대회준비 평창대회준비
# 16                                             오빠 부대 오빠부대
# 17      노인 버스 좌석 양보 단속 대통령 자리 양보 풍습 확대 강조 버스좌석 좌석양보 자리...
# 18                              산업 혁명 러다이트 운동 산업혁명 러다이트운동
# 19                              마키아벨리 국가 위기 해법 국가위기 위기의해법
# 20                                                     꽃씨
# 21                                                 글 짝 글짝
# 22                           지진 보험 도입 정부 지진보험 보험도입 지진보험도입
# 23                                           대권 인 잠룡 인의잠룡
# 24                                  장타 여왕 한판 승부 장타여왕 한판승부
# 25                                               배 구판 배구판
# 26                                           박영훈 완승 박영훈완승
# 27                                   내달 스포츠 사령관 선거 스포츠사령관
# 28      러시아 복수 스타 선수 금지 약물 해킹 폭로 스타선수 금지약물 약물해킹 러시아의복수...
# 29      코리아 오픈 테니스 한국 전원 외 코리아오픈 오픈테니스 테니스한국 한국전원 코리아오...
# ...                                                   ...
# 120805  지역 축제 원가 내달 공개 재정난 인천 축제 행사 지역축제 축제원가 원가내달 지역축...
# 120806  은행 직원 박 대통령 청년 펀드 가입 지시 박대통령 대통령청년 청년펀드 가입지시 박...
# 120807  법무부 국고 손실 환수 송무 팀 출범 국고손실 손실환수 환수송무 송무팀 팀출범 국고...
# 120808  수류탄 소지 추정 퇴역 군인 철원 행방불명 수류탄소지 소지추정 추정퇴역 퇴역군인 군...
# 120809  농촌 진흥 청도 음서 논란 직원 자녀 채용 특혜 의혹 농촌진흥 진흥청도 청도음서 직...
# 120810               한화 관중 모욕 전 악몽 재현 관중모욕 전악몽 악몽재현 전악몽재현
# 120811                               세계 신기록 할아버지 도전 세계신기록
# 120812  음란 행위 김수창 제주 지검 장 변호사 등록 허가 음란행위 제주지검 지검장 장변호사...
# 120813          대형 마트 병 인회 수기 설치 회수 대형마트 인회수기 수기설치 인회수기설치
# 120814             서울 낮 최고 기온 하순 서울낮 낮최고 최고기온 서울낮최고 낮최고기온
# 120815                             장례 때 장묘 방식 화장 장례때 장묘방식
# 120816                     강남 성형외과 건보 진료비 청구 강남성형외과 건보진료비
# 120817            희망 고문 쌍용 차 해고 대주주 인도 희망고문 쌍용차 차해고 쌍용차해고
# 120818                                               욕 변신
# 120819                       변방 좌파 대표 날 영국 노동당 변방좌파 영국노동당
# 120820                                      물 대신 오미자차 물대신
# 120821                           메르스 탓 해외여행 여행 비 메르스탓 여행비
# 120822                         왕 백성 박 대통령 특별 남발 박대통령 왕이백성
# 120823                                 식물 비자 자생지 복원 자생지복원
# 120824           박주선 정치 탈당 현역 의원 탈당 정치탈당 현역의원 의원탈당 현역의원탈당
# 120825               추석 현금 방출 금고 연 한국은행 금고연 연한국은행 금고연한국은행
# 120826  박주선 의원 정치 민주 연합 탈당 기자 회견 문 박주선의원 정치민주 민주연합 연합탈...
# 120827                                청계 재단 세상 이상 기부 청계재단
# 120828              검찰 제자 가혹 행위 교수 징역 구형 제자가혹 가혹행위 제자가혹행위
# 120829                                          이민호 수지 결별
# 120830  캐머런 영국 총리 피그 게이트 파문 패러디 봇물 캐머런영국 영국총리 피그게이트 패러...
# 120831                               연속 홈런 박병호 홈런 다 홈런박병호
# 120832  박주선 정치 의원 탈당 오늘 오후 기자 회견 정치의원 오늘오후 오후기자 기자회견 오...
# 120833  인천 공항 해킹 여권 번호 유출 실토 착각 인천공항 공항해킹 해킹여권 여권번호 인천...
# 120834  연세대 교수 한국사 교과서 국정 반대 성명 연세대교수 한국사교과서 교과서국정 한국사...
#
#                                         tokenized_content
# 0                                                      진실
# 1                                          세기 연인 커플 세기의연인
# 2                                              목소리 목소리 기사
# 3       정도 날 결정 일 결정 가뭄 단비 형국 잔치 형상 꿈 현실 형통 즐거움 근심 건강 ...
# 4
# 5       국내 운행 자동차 가운데 리콜 리콜 판정 조치 이번 조사 국내 완성 차 업체 리콜 ...
# 6       추석 연휴 전후 차례 지진 영남 지역 주민 공포 불안감 아파트 학교 고층 건물 안전...
# 7       중국 정부 우라늄 정제 필수 산화알루미늄 핵 미사일 개발 전용 물자 지속 북 수출 ...
# 8       롯데 그룹 수사 정점 신동빈 롯데 그룹 회장 피의자 신분 검찰 소환 조사 검찰 롯데...
# 9       노령 연금 역사 세기 말 부국강병 책 독일 통일 독일 제국 초대 총리 철혈 저금리 ...
# 10      인사 혁신 처 전문직 공무원 제도 도입 국제 통상 재난 안전 전문 필요 분야 지식 ...
# 11      아침 저녁 소매 끝 기운 송강 저녁 밤 창밖 빗소리 사미승 대답 손 달 시내 남쪽 ...
# 12      일자 면 전 우즈 박인비 전 우즈 박인비 일자 면 부음 사운드 오브 뮤직 딸 역 차...
# 13
# 14      서울 유명 대학 병원 수술실 월요일 목요일 아침 저녁 수술실 환자 외과 의사 교수 ...
# 15      리우 패럴림픽 메달 수 여자 보치아 금메달리스트 정호원 선수 기장 때 일 뇌성 마비...
# 16      전 사회부 초년 기자 때 가출 원조 교제 노숙 사회 이슈 청소년 문제 주제 기획 기...
# 17      시내버스 출퇴근 의사 김 모 수첩 특별 기록 그날 버스 좌석 양보 양보 연령 계층 ...
# 18      다보스 포럼 산업 혁명 주목 이후 대응책 마련 정부 분주 정치 대선 경쟁 화두 대전...
# 19      북한 핵 앞 민국 풍전등화 정치 추구 공자 말씀 현실 독재자 김정은 손 핵폭탄 위협...
# 20      직장 시기 하루 낮 퇴직 후 삶 저녁 남편 저녁 삶 농촌 생각 선택 시부모 세월 농...
# 21      글 짝 엄마 주방 저녁 글 짝 아빠 옆 엄마 글 짝 짝 엄마 프라이팬 두부 아빠 뚝...
# 22      경주 규모 지진 발생 규모 여진 국민 지진 불안감 증폭 지진 발생 예방 가능 거대 ...
# 23      조선 밤 시사 토크 쇼 강적 방송 대선 시점 대권 행보 채비 여야 인의 잠룡 출연 ...
# 24      미국 여자 프로 골프 투어 시즌 도전 무대 강원도 춘천 엘리시 안 강촌 골프장 사흘...
# 25      한국 배구 총괄 대한배구협회 외국인 선수 등록 문제 진흙탕 싸움 배경 국가 대표 팀...
# 26      총보 몫 판 박영훈 바둑 장점 단점 우변 공격 여유 추격 허용 결정 장면 치명타 방...
# 27      내달 대한체육회 회장 선거 앞 평가 이번 체육 회장 그동안 엘리트 체육 관장 대한체...
# 28      러시아 반격 러시아 해커 집단 세계 반도핑 기구 출전 팬시 베어스 투약 기록 공개 ...
# 29      코리아 오픈 테니스 한국 전원 장수정 장수정 패배 코리아 오픈 출전 한국 선수 본선...
# ...                                                   ...
# 120805  행정자치부 전국 지방 자치 단체 축제 행사 집 행비 전면 공개 재정 위기 초래 분별...
# 120806  박근혜 대통령 제안 시중 은행 청년 희망 펀드 출시 가운데 은행 직원 상대 펀드 가...
# 120807  법무부 국가 상대 부패 비리 불법 집단행동 국고 손실 전담 소송 진행 국고 손실 환...
# 120808  오후 강원 철원군 서면 와수리 육군 상사 전역 ㄱ 씨 수류탄 행방 신고 접수 경찰 ...
# 120809  농촌 진흥 청 직원 자녀 계약직 채용 무기 계약직 특혜 의혹 최근 간 채용 방직 공...
# 120810  한국 야구팬 최악 모욕 날 광주 타이거즈 한화 이글스 경기 홈 팀 만루 홈런 문제 ...
# 120811  전력 질주 원반 포환 장대높이뛰기 도전 할아버지 화제 미국 캘리포니아주 샌디에이고 ...
# 120812  길거리 음란 행위 물의 사직 김수창 제주 지검 변호사 활동 변호사 협회 김 지검 장...
# 120813  소주 맥주 빈병 값 인상 예고 가운데 대형 마트 병 인회 수기 설치 가정 빈병 회수...
# 120814  서울 낮 최고 기온 하순 날씨 날 기록 기상청 이날 날 햇볕 동해 안 자리 고기압 ...
# 120815  가족 장례 화장 선택 사람 자연 장 장례 장묘 장사 비용 평균 조사 한국 소비 자원...
# 120816  전국 성형외과 곳 가운데 건강 보험 진료비 청구 건강 보험 적용 환자 진료 건강 보...
# 120817  쌍용 자동차 해고 복직 문제 해결 대주주 마힌드라 그룹 인도 인도 마힌드라 그룹 아...
# 120818  김순옥 예전 문장 주어 자리 막장 드라마 대모 임성한 이름 전 오랜만 복귀 때 여타...
# 120819  영국 노동당 당 대표 제러미 코빈 주목 미국 민주당 대선 경선 열풍 사회주의자 버니...
# 120820  한겨레 자료 사진 동양 의학 예 식품 약 구분 날 음식 체질 병 정성 약 생각 바탕...
# 120821  중동 호흡기 증후군 취소 해외여행 전직 여행사 대표 검거 인천 남동 경찰서 단체 해...
# 120822  최재천 정치 민주 연합 정책 위 의장 박근혜 대통령 추석 국군 장병 특별 휴가증 특...
# 120823  산림청 국립 수목원 세계유산 한라산 연구원 국가 지정 식물 비자 자생지 공동 복원 ...
# 120824  박주선 정치 민주 연합 의원 이정우 선임 기자 박주선 정치 민주 연합 의원 탈당 선...
# 120825  추석 명절 서울 중구 한국은행 본점 직원 추석 자금 시중 은행 공급 방출 작업 김성...
# 120826  박주선 정치 민주 연합 의원 오후 국회 정론 관 기자 회견 탈당 선언 내년 총선 정...
# 120827  한겨레 버티컬 동영상 모바일 중심 콘텐츠 스마트폰 가로 필요 평소 이용 모습 영상 ...
# 120828  자신 맘 이유 수년 동안 제자 인분 가혹 행위 혐의 구속 기소 교수 징역 구형 수원...
# 120829  배우 이민호 결별 설 사실 오전 매체 이민호 수지 스케줄 연인 관계 정리 보도 수지...
# 120830  데이비드 캐머런 영국 총리 런던 다우닝가 총리 관저 라르스 뢰케 라스무센 덴마크 총...
# 120831  우문 마산 엔시 홈런 의미 박병호 답 홈런 상징 이비오 대표 홈런 타자 답 박병호 ...
# 120832  박주선 정치 민주 연합 의원 이정우 선임 기자 박주선 정치 민주 연합 의원 오후 기...
# 120833  뉴스 브리핑 아침 콘텐츠 가운데 주요 콘텐츠 독자 브리핑 배달 한겨레 배달 시작 인...
# 120834  한국사 교과서 국정 반대 각계 성명 가운데 연세대 교수 국정 추진 중단 촉구 성명 ...
#
# [120835 rows x 12 columns]>

# %% [markdown]
# ## Training

# %%
vectorizer = TfidfVectorizer(lowercase=False, 
                             max_features=None,
                             max_df=1.0, 
                             min_df=1,
                             use_idf=True,
                             smooth_idf=True,
                             sublinear_tf=False)

# %%
x_list = vectorizer.fit_transform(train_df.tokenized_title + train_df.tokenized_content)

# %%
print x_list.shape
print train_df.shape

# %%
x_list[0]

# %%
len(x_list.toarray())
print(dict(zip(vectorizer.get_feature_names(), vectorizer._tfidf.idf_)))
# x_list.stop_words()

# %% [markdown]
# ### Basic Models
# 1. Tf-idf and Cosine similarity
# 2. K-Means Algorithm

# %%
def cosine_distance(x_list):
    dist = 1 - cosine_similarity(x_list)
    return dist

# %%
num_clusters = len(topics)
num_clusters

# %%
t0 = time()
km = KMeans(n_clusters=num_clusters, n_jobs=-1)
km.fit(x_list)
clusters = km.labels_.tolist()
print("Done in %0.3fs." % (time() - t0))

# %%
print(len(clusters), len(train_df))

# %%
train_df['cluster'] = clusters

# %%
def match_cluster_topic(is_cluster):
    if(is_cluster):
        print("Cluster -> Topic")
        criteria = 'cluster'
        target = 'topic_idx'
    else:
        print("Topic -> Cluster")
        criteria = 'topic_idx'
        target = 'cluster'
        
    total_doc = 0    
    total_accuracy = 0    
    for i in range(0, num_clusters):
        criteria_set = train_df[train_df[criteria]==i]
        target_count = {}
        for j in range(0, num_clusters):
            target_set = criteria_set[criteria_set[target]==j]
            target_count[j] = len(target_set)
        max_target_idx = max(target_count.iteritems(), key=operator.itemgetter(1))[0]
        accuracy = 100*target_count[max_target_idx]/float(len(criteria_set))
        total_accuracy = total_accuracy + accuracy
        if(is_cluster):
            topic_str = topics[max_target_idx]
        else:
            topic_str = topics[i]
        print("#%d -> #%d Accuracy is %.4d/%.4d = %.10f \t %s" % (i, max_target_idx, target_count[max_target_idx], len(criteria_set), accuracy, topic_str))
        total_doc = total_doc + target_count[max_target_idx]
        
    print("%.4f" % (total_accuracy/num_clusters))
    print("%.4f" % (100 * total_doc/len(train_df)))

# %%
for idx in topics:
    topic = topics[idx]
    print("%.4d - %s" % (len(train_df[train_df.topic==topic]), topic))

# %%
match_cluster_topic(True)

# %%
match_cluster_topic(False)

# %%
# print_top_words(km, vectorizer.get_feature_names(), 20)

# %%
adjusted_rand_score(train_df.topic, km.labels_)

# %%
skf = StratifiedKFold(train_df.topic, n_folds=3)
cross_val_score(km, x_list, cv=skf)

# %%
df = train_df.drop(['_id', 'content', 'description', 'provider', 'providerNewsID', 'publishedAt'], axis=1)
two = df[df.cluster==3]
# two[two.topic_idx==4]
for idx in topics:
    print topics[idx], len(two[two.topic_idx==idx])
# two

# %%
two

# %%
cartesian = itertools.product(range(num_clusters), range(num_clusters))

temp = {
    'cluster': [],
    'topic_idx': [],
    'counts': []
}
for c, t in cartesian:
    clusters = df[df.cluster==c]
    topics = clusters[clusters.topic_idx==t]
    temp['cluster'].append(c)
    temp['topic_idx'].append(t)
    temp['counts'].append(len(topics))
    
results = pd.DataFrame(temp)
results = results[results.counts!=0]

# %%
# results[results.counts!=0]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(results.topic_idx, results.cluster, 'ro')
for index, row in results.iterrows():
    x = row['topic_idx']
    y = row['cluster']
    ax.annotate('  %d' % row['counts'], xy=(x,y), textcoords='data')
plt.axis([-1, 7, -1, 7])
plt.xlabel('Topic')
plt.ylabel('Cluster')

plt.grid()
plt.show()

# %% [markdown]
# ## Deep Learning

# %%
from gensim import models
from gensim.models import Doc2Vec
from gensim.models import Word2Vec
import gensim.models.doc2vec
from collections import OrderedDict
import multiprocessing
cores = multiprocessing.cpu_count()
assert gensim.models.doc2vec.FAST_VERSION > -1, "this will be painfully slow otherwise"

from random import shuffle

from collections import namedtuple

Articles = namedtuple('Articles', 'words tags split')

# %%
size = len(train_df) / 4
print size, len(train_df), size * 4
# Out:
# 30208 120835 120832

# %%
alldocs = []
for idx, row in train_df.iterrows():
    tokens = row['tokenized_title'].split(' ') + row['tokenized_content'].split(' ')
    words = tokens[1:] # why start from 1?
    tags = [idx] # `tags = [tokens[0]]` would also work at extra memory cost
    tmp = idx//size % 4
    split = ['train','test','extra','extra'][tmp]  # 25k train, 25k test, 25k extra
#     sentiment = [1.0, 0.0, 1.0, 0.0, None, None, None, None][tmp] # [12.5K pos, 12.5K neg]*2 then unknown
    alldocs.append(Articles(words, tags, split))

# %%
train_docs = [doc for doc in alldocs if doc.split == 'train']
test_docs = [doc for doc in alldocs if doc.split == 'test']
doc_list = alldocs[:]  # for reshuffling per pass

print('%d docs: %d train, %d test' % (len(doc_list), len(train_docs), len(test_docs)))
# Out:
# 120835 docs: 30211 train, 30208 test

# %%
words = [x.words for x in alldocs]
w2v = Word2Vec(words, size=100, window=5, min_count=5, workers=4)
w2v.save_word2vec_format("../datastore/w-w2v.p")

# %%
simple_models = [
    # PV-DM Distributed Momory Model of PV
    # w/concatenation - window=5 (both sides) approximates paper's 10-word total window size
    Doc2Vec(dm=1, dm_concat=1, size=100, window=5, negative=5, hs=0, min_count=2, workers=cores),
    # PV-DBOW Distributed Bag of Words version of PV
    Doc2Vec(dm=0, size=100, negative=5, hs=0, min_count=2, workers=cores),
    # PV-DM w/average
    Doc2Vec(dm=1, dm_mean=1, size=100, window=10, negative=5, hs=0, min_count=2, workers=cores),
]

# %%
simple_models[0].load_word2vec_format("../datastore/w-w2v.p")

# %%
# speed setup by sharing results of 1st model's vocabulary scan
simple_models[0].build_vocab(alldocs)  # PV-DM/concat requires one special NULL word so it serves as template

# %%
print simple_models[0]
for model in simple_models[1:]:
    model.reset_from(simple_models[0])
    print(model)

models_by_name = OrderedDict((str(model), model) for model in simple_models)

# %%
from gensim.test.test_doc2vec import ConcatenatedDoc2Vec
models_by_name['dbow+dmm'] = ConcatenatedDoc2Vec([simple_models[1], simple_models[2]])
models_by_name['dbow+dmc'] = ConcatenatedDoc2Vec([simple_models[1], simple_models[0]])

# %%
alpha, min_alpha, passes = (0.025, 0.001, 20)
alpha_delta = (alpha - min_alpha) / passes

for epoch in range(passes):
    shuffle(doc_list)  # shuffling gets best results

    for name, train_model in models_by_name.items():
        train_model.alpha, train_model.min_alpha = alpha, alpha
        train_model.train(doc_list)
        print("%i passes : %s" % (epoch + 1), name)

    print('completed pass %i at alpha %f' % (epoch + 1, alpha))
    alpha -= alpha_delta

# %%
for name, train_model in models_by_name.items():
    train_model.save("../datastore/" + name)
    print "saved " + name
